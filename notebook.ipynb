# %%
import pdfplumber
import pandas as pd

def extract_table_from_pdf(pdf_path, has_header):
    data = []
    header = None
    with pdfplumber.open(pdf_path) as pdf:
        for page_num, page in enumerate(pdf.pages, start=1):
            # Extract table settings: Look for lines
            tables = page.extract_tables({
                "vertical_strategy": "lines",
                "horizontal_strategy": "lines"
            })
            
            for table in tables:
                # If header is not set and has_header is True, set header and skip the first row
                if has_header and header is None:
                    header = table[0] + ["page"]
                    start_row_index = 1
                    continue  # Skip the rest of the loop to avoid adding the header as data

                # If header is not set and has_header is False, create a default header
                if header is None:
                    header = [f"column_{i}" for i in range(len(table[0]))] + ["page"]
                    start_row_index = 0


                # Iterate over the table rows, starting from the appropriate index
                for row in table[start_row_index:]:
                    row_with_page = row + [page_num]
                    data.append(row_with_page)
                
    return header, data


council = "East Lothian"
council_mappings = {"Salford": (1, True), "Renfrewshire": (2, True), "East Lothian": (3, False)}
number, has_header = council_mappings[council]
pdf_path = f"sample_pdf{number}.pdf"

# %%
column_mappings = {
            "Salford": {"REG": "vrm", "VEHICLE TYPE": "make"},
            "Renfrewshire": {"column_1": "vrm", "column_2": "make"},
            "East Lothian": {
                "column_0": "vrm",
                "column_1": "vrm",
                "column_3": "make",
                "column_4": "make",
                "column_6": "model",
                "column_7": "model",
            },
        }

# %%
header, table_data = extract_table_from_pdf(pdf_path, has_header=has_header)

df = pd.DataFrame(table_data, columns=header)

df
# Out:
#      column_0      column_1      column_2  column_3  column_4 column_5  \
# 0                  GF16 HJE                          Vauxhall
# 1    DL15 XXT          None          None  Vauxhall      None     None
# 2                  CP17 YXJ                              FORD
# 3    MM70 JBV          None          None  Vauxhall      None     None
# 4                  GD66 OMC                             Skoda
# ..        ...           ...           ...       ...       ...      ...
# 234  SD17 OUF          None          None   Peugeot      None     None
# 235                SK62 UPV                           Renault
# 236  MF68 UYR          None          None      Ford      None     None
# 237                LM68 LXF                          Vauxhall
# 238  SF68 KLO  Ford Pro Cab  Ford Pro Cab         7      None     None
#
#                     column_6        column_7 column_8  page
# 0                              Octavia S TDi            1.0
# 1                      Astra            None     None   1.0
# 2                                    TRANSIT            1.0
# 3                      Corsa            None     None   1.0
# 4                             Octavia Estate            1.0
# ..                       ...             ...      ...   ...
# 234  Premier RS Blue HDI S/S            None     None   6.0
# 235                                   Trafic            6.0
# 236                  Tourneo            None     None   6.0
# 237                                   Vivaro            6.0
# 238                     None            None     None   NaN
#
# [239 rows x 10 columns]

# %%
df.head(50)
# Out:
#     column_0  column_1 column_2     column_3    column_4 column_5  \
# 0             GF16 HJE                          Vauxhall
# 1   DL15 XXT      None     None     Vauxhall        None     None
# 2             CP17 YXJ                              FORD
# 3   MM70 JBV      None     None     Vauxhall        None     None
# 4             GD66 OMC                             Skoda
# 5   YE66 UJC      None     None      Renault        None     None
# 6             NK17 DMZ                          Vauxhall
# 7   WF71 EXU      None     None      Hyundai        None     None
# 8             SC21 WHH                            Toyota
# 9   FP15 RDY      None     None     Vauxhall        None     None
# 10            FJ17 XKX                          Vauxhall
# 11  FN65 OYW      None     None     Vauxhall        None     None
# 12             T10 TTX                          Mercedes
# 13   YC71EBJ      None     None          Kia        None     None
# 14            EGZ 5639                        Volkswagen
# 15  YC72 UZR      None     None           MG        None     None
# 16            DP69 ELW                              Ford
# 17  VN71 YHD      None     None   Volkswagon        None     None
# 18  SD15 VPC      None     None                Mercedes-
# 19      None      None     None         None        Benz     None
# 20  SB14 BTE      None     None     Vauxhall        None     None
# 21   DC21ACS      None     None                Mercedes-
# 22      None      None     None         None        Benz     None
# 23  FN65 OYA      None     None     Vauxhall        None     None
# 24             T44 GGT                             Skoda
# 25  GL17 HRE      None     None        Skoda        None     None
# 26            YR62 HME                          Vauxhall
# 27  DK69 CXZ      None     None      Peugeot        None     None
# 28            NK63 FDJ                              Seat
# 29  NX09 XDS      None     None     Vauxhall        None     None
# 30  YG67 ZZD      None     None      Peugeot        None     None
# 31      None      None     None         None        None     None
# 32  SN19 BLG      None     None       Toyota        None     None
# 33             GC21ORX                             Skoda
# 34  FN65 OXZ      None     None     Vauxhall        None     None
# 35            FG69 EOD                              Ford
# 36  BV20 PEO      None     None        Skoda        None     None
# 37            FM23 DWP                             Dacia
# 38  SB18 PXW      None     None  Nissan Leaf        None     None
# 39   YP18WXO      None     None                 Vauxhall
# 40      None      None     None         None      Vivaro     None
# 41   H22 LAH      None     None      Hyundai        None     None
# 42            MF71 VDT                            Toyota
# 43  SK22 VFW      None     None          MG5        None     None
# 44            GK23 PZX                             Skoda
# 45   JM11KAS      None     None        Skoda        None     None
# 46             NV68KMU                          Vauxhall
# 47    L7 GWR      None     None      Hyundai        None     None
# 48            HN67 MXJ                             Skoda
# 49   SF66GDY      None     None      Peugeot        None     None
#
#                            column_6                 column_7 column_8  page
# 0                                              Octavia S TDi            1.0
# 1                             Astra                     None     None   1.0
# 2                                                    TRANSIT            1.0
# 3                             Corsa                     None     None   1.0
# 4                                             Octavia Estate            1.0
# 5     Trafic LL29 Sport Energy\nDCI                     None     None   1.0
# 6                                               Vivaro Combi            1.0
# 7             IONiQ PREMIUM HEV S-A                     None     None   1.0
# 8                                                    Corolla            1.0
# 9          Astra Tech Line CDTi S/S                     None     None   1.0
# 10                                                  Insignia            1.0
# 11        Astra Tech Line CDTI\nS/S                     None     None   1.0
# 12                                     E350E SE Premium Auto            1.0
# 13        Ceed 2 Nav CRDI ISG\nMHEV                     None     None   1.0
# 14                                                                      1.0
# 15                         5 Excite                     None     None   1.0
# 16                                           Tourneo Courier            1.0
# 17                            Caddy                     None     None   1.0
# 18                                   Vito 116 Bluetec Tourer            1.0
# 19                             None                      Pro     None   1.0
# 20                  Zafira Exclusiv                     None     None   1.0
# 21                 Evito Tourer Pro                     None     None   1.0
# 22                             None                     None     None   1.0
# 23         Astra Tech Line CDTi S/S                     None     None   1.0
# 24                                                    Superb            1.0
# 25                           Superb                     None     None   1.0
# 26                                           Zafira Exclusiv            1.0
# 27                            Boxer                     None     None   1.0
# 28                                                    Toledo            1.0
# 29      Insignia Exclusiv 160\nCDTI                     None     None   1.0
# 30                                      508 GT line Blue HDI            2.0
# 31                             None                      S/S     None   2.0
# 32                          Corolla                     None     None   2.0
# 33                                            Octavia SE TDI            2.0
# 34        Astra Tech Line CDTI\nS/S                     None     None   2.0
# 35                                           Tourneo Courier            2.0
# 36                          Octavia                     None     None   2.0
# 37                                          Jogger Essential            2.0
# 38                                                      None     None   2.0
# 39                              X83                     None     None   2.0
# 40                             None                     None     None   2.0
# 41  Tucson SE Connect T-\nGDI HEV A                     None     None   2.0
# 42                                             Corola Hybred            2.0
# 43           Electric Estate Excite                     None     None   2.0
# 44                                        Octavia 1.0 TSi SE            2.0
# 45                      Superb S TD                     None     None   2.0
# 46                                                  Insignia            2.0
# 47      Kona SE Connect T-GDI\nMHEV                     None     None   2.0
# 48                                                   Octavia            2.0
# 49                            Boxer                     None     None   2.0

# %%
def update_headers(column_mappings, df, council):
    column_map = column_mappings[council]
    # Rename the columns using the provided column mapping
    df.rename(columns=column_map, inplace=True)
    
    return df

# %%
df = update_headers(column_mappings, df, council)
df.to_csv(f"output_{council}.csv", index=False)

# %%
def clean_dataframe(df, column_mappings, council):

    clean_headers = list(set(column_mappings[council].values()))

    print(df)
    print(clean_headers)

    has_null = df[clean_headers].isnull().values.any()
    if has_null:
    
        # Initialize a list to hold the cleaned data
        cleaned_data = []

        # Iterate over the DataFrame rows
        for index, row in df.iterrows():
            # Initialize a dictionary to hold the non-null values for the current row
            non_null_values = {header: None for header in clean_headers}
            
            # Iterate over each header and collect the last non-null value if available
            for header in clean_headers:

                # Get all the values from the columns that were mapped to the current header
                values = row[header].dropna().tolist()
                if values:  # If there are any non-null values
                    # Assign the last non-null value to the corresponding header in the dictionary
                    non_null_values[header] = values[-1]
            
            # Append the dictionary with non-null values to the cleaned data list
            cleaned_data.append(non_null_values)

        # Create a new DataFrame using the cleaned data
        cleaned_df = pd.DataFrame(cleaned_data, columns=clean_headers)

        return cleaned_df
    
    return df

# %%
df_clean = clean_dataframe(df, column_mappings, council)
# Out:
#           vrm           vrm      column_2      make      make column_5  \
# 0                  GF16 HJE                          Vauxhall
# 1    DL15 XXT          None          None  Vauxhall      None     None
# 2                  CP17 YXJ                              FORD
# 3    MM70 JBV          None          None  Vauxhall      None     None
# 4                  GD66 OMC                             Skoda
# ..        ...           ...           ...       ...       ...      ...
# 234  SD17 OUF          None          None   Peugeot      None     None
# 235                SK62 UPV                           Renault
# 236  MF68 UYR          None          None      Ford      None     None
# 237                LM68 LXF                          Vauxhall
# 238  SF68 KLO  Ford Pro Cab  Ford Pro Cab         7      None     None
#
#                        model           model column_8  page
# 0                              Octavia S TDi            1.0
# 1                      Astra            None     None   1.0
# 2                                    TRANSIT            1.0
# 3                      Corsa            None     None   1.0
# 4                             Octavia Estate            1.0
# ..                       ...             ...      ...   ...
# 234  Premier RS Blue HDI S/S            None     None   6.0
# 235                                   Trafic            6.0
# 236                  Tourneo            None     None   6.0
# 237                                   Vivaro            6.0
# 238                     None            None     None   NaN
#
# [239 rows x 10 columns]
# ['vrm', 'model', 'make']

# %%
df_clean.to_csv(f"output_clean_{council}.csv", index=False)

# %%
df_clean
# Out:
#               vrm                    model      make
# 0        GF16 HJE            Octavia S TDi  Vauxhall
# 1        DL15 XXT                    Astra  Vauxhall
# 2        CP17 YXJ                  TRANSIT      FORD
# 3        MM70 JBV                    Corsa  Vauxhall
# 4        GD66 OMC           Octavia Estate     Skoda
# ..            ...                      ...       ...
# 234      SD17 OUF  Premier RS Blue HDI S/S   Peugeot
# 235      SK62 UPV                   Trafic   Renault
# 236      MF68 UYR                  Tourneo      Ford
# 237      LM68 LXF                   Vivaro  Vauxhall
# 238  Ford Pro Cab                     None         7
#
# [239 rows x 3 columns]
